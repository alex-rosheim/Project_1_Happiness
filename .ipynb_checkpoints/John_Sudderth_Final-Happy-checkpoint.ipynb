# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

api_key = "558e56b6dce2cececb94ac03459570d9"

# %%
rain_df = pd.read_csv('Annual_Precipitation.csv')

rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
sun_df = pd.read_csv('Sunniness_by_Ranking.csv')
sun_df.columns = ['State', 'Sun %', 'Total Hours', 'Days']
sun_df.head()
# Out:
#         State  Sun %  Total Hours  Days
# 0     Alabama     58         2641    99
# 1      Alaska     41         2061    61
# 2     Arizona     85         3806   193
# 3    Arkansas     61         2771   123
# 4  California     68         3055   146

# %%
snow_df = pd.read_csv('annual_snow.csv')
snow_df.head()
# Out:
#         State Inches
# 0     Alabama    1.6
# 1      Alaska   74.5
# 2     Arizona    0.3
# 3    Arkansas    5.2
# 4  California      0

# %%
state = []
inches = []

i = 0
for row in rain_df.State:
   #for every row append the city at index 0 and state at index 1
    state.append(rain_df.State)
    inches.append(rain_df.Inches)
    i += 1

# %%
sun_state = []
sun_days = []

i = 0
for row in sun_df.Days:
   #for every row append the city at index 0 and state at index 1
    sun_state.append(sun_df.State)
    sun_days.append(sun_df.Days)
    i += 1

# %%
snow_state = []
snow_inches = []

i = 0
for row in snow_df.Inches:
   #for every row append the city at index 0 and state at index 1
    snow_state.append(snow_df.State)
    snow_inches.append(snow_df.Inches)
    i += 1

# %%
starter_df = pd.read_csv('top_25_key.csv')

starter_df.head(10)
# Out:
#    rank_key                        metro
# 0         1            Boulder, Colorado
# 1         2       Santa Cruz, California
# 2         2      Watsonville, California
# 3         3    Charlottesville, Virginia
# 4         4       Fort Collins, Colorado
# 5         5  San Luis Obispo, California
# 6         6         San Jose, California
# 7         7                  Provo, Utah
# 8         8      Bridgeport, Connecticut
# 9         8        Stamford, Connecticut

# %%
cities = []
states = []
rank = []


i = 0
for row in starter_df.metro:
   #for every row append the city at index 0 and state at index 1
    cities.append(starter_df.metro.str.split(',')[i][0])
    states.append(starter_df.metro.str.split(',')[i][1])
    rank.append(i+1)
    
    i += 1


city_state = pd.DataFrame({"City": cities,
                          "State": states,
                          "Rank": rank})
city_state.head()
# Out:
#               City        State  Rank
# 0          Boulder     Colorado     1
# 1       Santa Cruz   California     2
# 2      Watsonville   California     3
# 3  Charlottesville     Virginia     4
# 4     Fort Collins     Colorado     5

# %%
namelist = []
cityidlist = []
latlist = []
lonlist = []
templist = []
humidlist = []
cloudlist = []
windspeedlist = []
countrylist = []
rainlist = []
ranklist = []


#Then construct the URL
#make sure to use imperial
#start with a base
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial'

#then add your api key and create a unique url for every city in cities (list i created earlier)
#everything has to be in lists
#open weather api is as follows: http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=houston

x=0

for city in cities:
    
    if city == "Barnstable Town":
        query_url = base_url + '&appid=' + str(api_key) + '&q=Barnstable'
        response = requests.get(query_url)
        json_response = response.json()
        x = x + 1
        print('Retrieving Data for City #' + str(x) + ' of ' + str((len(cities))) + " | " + city +","+json_response['sys']['country'])
        namelist.append(json_response['name'])
        cityidlist.append(json_response['id'])
        latlist.append(json_response['coord']['lat'])
        lonlist.append(json_response['coord']['lon'])
        templist.append(json_response['main']['temp_max'])
        humidlist.append(json_response['main']['humidity'])
        cloudlist.append(json_response['clouds']['all'])
        windspeedlist.append(json_response['wind']['speed'])
        countrylist.append(json_response['sys']['country'])
        ranklist.append(x)
        
    else:
        try:
            query_url = base_url + '&appid=' + str(api_key) + '&q=' + str(city)
            response = requests.get(query_url)
            json_response = response.json()
            x = x + 1
            print('Retrieving Data for City #' + str(x) + ' of ' + str((len(cities))) + " | " + city +","+json_response['sys']['country'])
            namelist.append(json_response['name'])
            cityidlist.append(json_response['id'])
            latlist.append(json_response['coord']['lat'])
            lonlist.append(json_response['coord']['lon'])
            templist.append(json_response['main']['temp_max'])
            humidlist.append(json_response['main']['humidity'])
            cloudlist.append(json_response['clouds']['all'])
            windspeedlist.append(json_response['wind']['speed'])
            countrylist.append(json_response['sys']['country'])
            rainlist.append(rain_df['Inches'])
            ranklist.append(x)
            print(query_url)
        except KeyError:
            namelist.append(np.nan)
            cityidlist.append(np.nan)
            latlist.append(np.nan)
            lonlist.append(json_response['coord']['lon'])
            templist.append(np.nan)
            humidlist.append(np.nan)
            cloudlist.append(np.nan)
            windspeedlist.append(np.nan)
            countrylist.append(np.nan)
            ranklist.append(x)
            x = x + 1
            print("City not Found, Moving on to next City...")
            continue
# Out:
# Retrieving Data for City #1 of 43 | Boulder,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Boulder
# Retrieving Data for City #2 of 43 | Santa Cruz,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Santa Cruz
# Retrieving Data for City #3 of 43 | Watsonville,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Watsonville
# Retrieving Data for City #4 of 43 | Charlottesville,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Charlottesville
# Retrieving Data for City #5 of 43 | Fort Collins,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Fort Collins
# Retrieving Data for City #6 of 43 | San Luis Obispo,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=San Luis Obispo
# Retrieving Data for City #7 of 43 | San Jose,PH
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=San Jose
# Retrieving Data for City #8 of 43 | Provo,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Provo
# Retrieving Data for City #9 of 43 | Bridgeport,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Bridgeport
# Retrieving Data for City #10 of 43 | Stamford,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Stamford
# Retrieving Data for City #11 of 43 | Norwalk,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Norwalk
# Retrieving Data for City #12 of 43 | Barnstable Town,US
# Retrieving Data for City #13 of 43 | Anchorage,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Anchorage
# Retrieving Data for City #14 of 43 | Naples,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Naples
# Retrieving Data for City #15 of 43 | Immokalee,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Immokalee
# Retrieving Data for City #16 of 43 | Marco Island,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Marco Island
# Retrieving Data for City #17 of 43 | Santa Maria,BR
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Santa Maria
# Retrieving Data for City #18 of 43 | Santa Barbara,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Santa Barbara
# Retrieving Data for City #19 of 43 | Salina,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Salina
# Retrieving Data for City #20 of 43 | North Port,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=North Port
# Retrieving Data for City #21 of 43 | Sarasota,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Sarasota
# Retrieving Data for City #22 of 43 | Bradenton,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Bradenton
# Retrieving Data for City #23 of 43 | Honolulu,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Honolulu
# Retrieving Data for City #24 of 43 | Ann Arbor,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Ann Arbor
# Retrieving Data for City #25 of 43 | San Francisco,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=San Francisco
# Retrieving Data for City #26 of 43 | Oakland,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Oakland
# Retrieving Data for City #27 of 43 | Hayward,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Hayward
# Retrieving Data for City #28 of 43 | Colorado Springs,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Colorado Springs
# Retrieving Data for City #29 of 43 | Manchester,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Manchester
# Retrieving Data for City #30 of 43 | Nashua,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Nashua
# Retrieving Data for City #31 of 43 | Oxnard,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Oxnard
# Retrieving Data for City #32 of 43 | Thousand Oaks,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Thousand Oaks
# Retrieving Data for City #33 of 43 | Ventura,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Ventura
# Retrieving Data for City #34 of 43 | Washington,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Washington
# Retrieving Data for City #35 of 43 | Arlington,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Arlington
# Retrieving Data for City #36 of 43 | Alexandria,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Alexandria
# Retrieving Data for City #37 of 43 | Minneapolis,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Minneapolis
# Retrieving Data for City #38 of 43 | Saint Paul,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Saint Paul
# Retrieving Data for City #39 of 43 | Bloomington,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Bloomington
# Retrieving Data for City #40 of 43 | San Diego,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=San Diego
# Retrieving Data for City #41 of 43 | Carlsbad,CZ
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Carlsbad
# Retrieving Data for City #42 of 43 | Portland,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Portland
# Retrieving Data for City #43 of 43 | Austin,US
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=Austin

# %%
# Convert retrieved lists to a dictionary first and then to a dataframe
# formatting for creating a dictionary is       variable_name = {"Key": value, "Key": value, etc}

weather_dict = {"Name": namelist,
                "State": states,
               "Country_id": cityidlist,
                "Country": countrylist,
                "Cloudiness (%)": cloudlist,
                "Max Temperature (F)": templist,
                "Latitude (Deg)": latlist,
                "Longitude (Deg)": lonlist,
                "Humidity (%)": humidlist,
                "UV_Index": uvlist,
                "Wind Speed (mph)": windspeedlist,
                "Ranking" : ranklist
               }

#create the dataframe from the dictionary
#format is vairable_name = pd.DataFrame(name of dictionary)
weather_df = pd.DataFrame(weather_dict)

#Drop the Nan Values
weather_df = weather_df.dropna(how='any')

weather_df.head(50)
# Out:
#                 Name                  State  Country_id Country  \
# 0            Boulder               Colorado     5574991      US
# 1         Santa Cruz             California     5393052      US
# 2        Watsonville             California     5407529      US
# 3    Charlottesville               Virginia     4752031      US
# 4       Fort Collins               Colorado     5577147      US
# 5    San Luis Obispo             California     5392323      US
# 6           San Jose             California     1689431      PH
# 7              Provo                   Utah     5780026      US
# 8         Bridgeport            Connecticut     5282804      US
# 9           Stamford            Connecticut     4843564      US
# 10           Norwalk            Connecticut     5377995      US
# 11        Barnstable          Massachusetts     4929771      US
# 12         Anchorage                 Alaska     5879400      US
# 13            Naples                Florida     4165565      US
# 14         Immokalee                Florida     4159553      US
# 15      Marco Island                Florida     4163384      US
# 16       Santa Maria             California     3450083      BR
# 17     Santa Barbara             California     5392952      US
# 18            Salina             California     4550364      US
# 19        North Port                Florida     4166274      US
# 20          Sarasota                Florida     4172131      US
# 21         Bradenton                Florida     4148708      US
# 22          Honolulu                 Hawaii     5856195      US
# 23         Ann Arbor               Michigan     4984247      US
# 24     San Francisco             California     5391959      US
# 25           Oakland             California     5378538      US
# 26           Hayward             California     5355933      US
# 27  Colorado Springs               Colorado     5417598      US
# 28        Manchester          New Hampshire     5089178      US
# 29            Nashua          New Hampshire     5090046      US
# 30            Oxnard             California     5380184      US
# 31     Thousand Oaks             California     5402405      US
# 32           Ventura             California     5405878      US
# 33    Washington DC.   District of Columbia     4366164      US
# 34         Arlington               Virginia     4744709      US
# 35        Alexandria               Virginia     4314550      US
# 36       Minneapolis              Minnesota     5037649      US
# 37        Saint Paul              Minnesota     5045360      US
# 38       Bloomington              Minnesota     4885164      US
# 39         San Diego             California     5391811      US
# 40          Carlsbad             California     3339539      CZ
# 41          Portland                  Maine     5746545      US
# 42            Austin                  Texas     4671654      US
#
#     Cloudiness (%)  Max Temperature (F)  Latitude (Deg)  Longitude (Deg)  \
# 0               40                20.12           40.02          -105.27
# 1                1                60.80           36.97          -122.03
# 2                1                57.20           36.91          -121.75
# 3                1                37.22           38.03           -78.48
# 4               40                19.40           40.55          -105.07
# 5                1                57.92           35.28          -120.66
# 6               44                78.55           15.79           120.99
# 7                1                37.94           40.23          -111.66
# 8               75                42.08           41.17           -73.20
# 9               90                42.08           41.05           -73.54
# 10               1                66.02           33.91          -118.08
# 11              75                48.92           41.70           -70.30
# 12              75                42.26           61.22          -149.89
# 13               1                66.20           26.14           -81.79
# 14              90                66.20           26.42           -81.42
# 15              75                66.20           25.94           -81.72
# 16              75                77.00          -29.69           -53.81
# 17               1                71.06           34.42          -119.70
# 18              40                30.20           36.29           -95.15
# 19              90                64.40           27.04           -82.24
# 20              90                64.40           27.34           -82.53
# 21              40                62.06           27.50           -82.57
# 22              90                80.06           21.30          -157.86
# 23              90                25.70           42.27           -83.73
# 24              20                60.80           37.78          -122.42
# 25              20                60.80           37.80          -122.27
# 26              20                60.80           37.67          -122.08
# 27              90                23.00           38.83          -104.83
# 28              75                44.96           43.00           -71.45
# 29              75                44.96           42.77           -71.47
# 30              20                71.06           34.20          -119.18
# 31              20                68.00           34.17          -118.84
# 32               1                71.06           34.28          -119.29
# 33              75                37.94           38.90           -77.04
# 34              75                37.94           38.89           -77.08
# 35               1                39.92           31.31           -92.44
# 36               1                -2.93           44.98           -93.27
# 37               1                -2.21           44.95           -93.10
# 38               1                10.40           40.47           -88.99
# 39              20                66.92           32.72          -117.16
# 40              90                26.60           50.23            12.87
# 41              40                48.92           45.52          -122.67
# 42               1                52.16           30.27           -97.74
#
#     Humidity (%)  UV_Index  Wind Speed (mph)  Ranking
# 0             92      4.29              3.36        1
# 1             82      4.63              4.70        2
# 2             54      4.65              4.70        3
# 3             49      4.53              3.36        4
# 4             92      4.23              3.36        5
# 5             79      4.70             10.29        6
# 6             66      4.47              3.85        7
# 7             85      4.31              3.36        8
# 8             67      4.78             16.11        9
# 9             63      4.76             12.75       10
# 10            51      4.61              4.70       11
# 11           100      4.89              8.05       12
# 12            82      4.55             12.75       13
# 13            87      4.33              7.20       14
# 14            77      4.37              7.20       15
# 15            93      4.34              8.77       16
# 16            83      4.58             11.41       17
# 17            55      4.70              4.74       18
# 18            58      4.02              6.93       19
# 19            72      4.31             10.29       20
# 20            72      4.28             10.29       21
# 21            74      4.28              8.05       22
# 22            78      4.46              6.93       23
# 23            80      4.23             17.22       24
# 24            63      4.62              4.07       25
# 25            63      4.62              4.07       26
# 26            63      4.63              2.62       27
# 27            91      4.23              6.93       28
# 28            70      3.57             10.29       29
# 29            70      4.84             10.29       30
# 30            28      4.67             12.75       31
# 31            28      4.65             12.75       32
# 32            55      4.69              3.96       33
# 33            54      4.57             10.29       34
# 34            54      4.57             10.29       35
# 35            85      4.02              2.95       36
# 36            57      4.01             11.41       37
# 37            61      4.01             12.75       38
# 38            76      4.16             24.16       39
# 39            62      4.57              6.93       40
# 40            92      3.24              5.82       41
# 41            70      4.61              2.28       42
# 42            44      4.09              5.82       43

# %%
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
sun_df.head()
# Out:
#         State  Sun %  Total Hours  Days
# 0     Alabama     58         2641    99
# 1      Alaska     41         2061    61
# 2     Arizona     85         3806   193
# 3    Arkansas     61         2771   123
# 4  California     68         3055   146

# %%
snow_df.head()
# Out:
#         State Inches
# 0     Alabama    1.6
# 1      Alaska   74.5
# 2     Arizona    0.3
# 3    Arkansas    5.2
# 4  California      0

# %%
sun_df.reset_index('State')
sun_df.head()
# Out:
#             Sun %  Total Hours  Days
# State
# Alabama        58         2641    99
# Alaska         41         2061    61
# Arizona        85         3806   193
# Arkansas       61         2771   123
# California     68         3055   146

# %%
rain_df.set_index("State", drop=True, inplace=True)
rain_df.head()
# Out:
#             Inches  Milli­metres  Rank
# State
# Alabama       58.3          1480     4
# Alaska        22.5           572    39
# Arizona       13.6           345    47
# Arkansas      50.6          1284     8
# California    22.2           563    40

# %%
snow_df.set_index("State", drop=True, inplace=True)
snow_df.head()
# Out:
#            Inches
# State
# Alabama       1.6
# Alaska       74.5
# Arizona       0.3
# Arkansas      5.2
# California      0

# %%
def get_rain(row):
    rain_dic = rain_df.to_dict(orient="index")
    state=row["State"]
    inches=rain_dic[state]["Inches"]
    return inches
weather_df=weather_df[weather_df["State"]!="District of Columbia"]
weather_df["State"]=weather_df["State"].apply(lambda x: x.strip())
weather_df['Rainfall'] = weather_df.apply(get_rain,axis=1)
weather_df.head()
# Out:
#               Name       State  Country_id Country  Cloudiness (%)  \
# 0          Boulder    Colorado     5574991      US              40
# 1       Santa Cruz  California     5393052      US               1
# 2      Watsonville  California     5407529      US               1
# 4     Fort Collins    Colorado     5577147      US              40
# 5  San Luis Obispo  California     5392323      US               1
#
#    Max Temperature (F)  Latitude (Deg)  Longitude (Deg)  Humidity (%)  \
# 0                20.12           40.02          -105.27            92
# 1                60.80           36.97          -122.03            82
# 2                57.20           36.91          -121.75            54
# 4                19.40           40.55          -105.07            92
# 5                57.92           35.28          -120.66            79
#
#    UV_Index  Wind Speed (mph)  Ranking  Rainfall  Sunshine
# 0      4.29              3.36        1      15.9       136
# 1      4.63              4.70        2      22.2       146
# 2      4.65              4.70        3      22.2       146
# 4      4.23              3.36        5      15.9       136
# 5      4.70             10.29        6      22.2       146

# %%
def get_sun(row):
    sun_dic = sun_df.to_dict(orient="index")
    state=row["State"]
    days=sun_dic[state]["Days"]
    return days

weather_df=weather_df[weather_df["State"]!="Virginia"]
weather_df["State"]=weather_df["State"].apply(lambda x: x.strip())
weather_df['Sunshine'] = weather_df.apply(get_sun,axis=1)
weather_df.head()
# Out:
#               Name       State  Country_id Country  Cloudiness (%)  \
# 0          Boulder    Colorado     5574991      US              40
# 1       Santa Cruz  California     5393052      US               1
# 2      Watsonville  California     5407529      US               1
# 4     Fort Collins    Colorado     5577147      US              40
# 5  San Luis Obispo  California     5392323      US               1
#
#    Max Temperature (F)  Latitude (Deg)  Longitude (Deg)  Humidity (%)  \
# 0                20.12           40.02          -105.27            92
# 1                60.80           36.97          -122.03            82
# 2                57.20           36.91          -121.75            54
# 4                19.40           40.55          -105.07            92
# 5                57.92           35.28          -120.66            79
#
#    UV_Index  Wind Speed (mph)  Ranking  Rainfall  Sunshine
# 0      4.29              3.36        1      15.9       136
# 1      4.63              4.70        2      22.2       146
# 2      4.65              4.70        3      22.2       146
# 4      4.23              3.36        5      15.9       136
# 5      4.70             10.29        6      22.2       146

# %%
def get_snow(row):
    snow_dic = snow_df.to_dict(orient="index")
    state=row["State"]
    days=snow_dic[state]["Inches"]
    return days

weather_df=weather_df[weather_df["State"]!="Connecticut"]
weather_df=weather_df[weather_df["State"]!="Tennessee"]

weather_df["State"]=weather_df["State"].apply(lambda x: x.strip())
weather_df['Snow'] = weather_df.apply(get_snow,axis=1)
weather_df.head()
# Out:
#               Name       State  Country_id Country  Cloudiness (%)  \
# 0          Boulder    Colorado     5574991      US              40
# 1       Santa Cruz  California     5393052      US               1
# 2      Watsonville  California     5407529      US               1
# 4     Fort Collins    Colorado     5577147      US              40
# 5  San Luis Obispo  California     5392323      US               1
#
#    Max Temperature (F)  Latitude (Deg)  Longitude (Deg)  Humidity (%)  \
# 0                20.12           40.02          -105.27            92
# 1                60.80           36.97          -122.03            82
# 2                57.20           36.91          -121.75            54
# 4                19.40           40.55          -105.07            92
# 5                57.92           35.28          -120.66            79
#
#    UV_Index  Wind Speed (mph)  Ranking  Rainfall  Sunshine  Snow
# 0      4.29              3.36        1      15.9       136  19.1
# 1      4.63              4.70        2      22.2       146     0
# 2      4.65              4.70        3      22.2       146     0
# 4      4.23              3.36        5      15.9       136  19.1
# 5      4.70             10.29        6      22.2       146     0

# %%
sun_dic = sun_df.to_dict(orient="index")
# rain_dic

# # d = {112: 'en', 113: 'es', 114: 'es', 111: 'en'}
# # df['D'] = df['U'].map(d)
# # df



weather_df.head(50)
# Out:
#                 Name          State  Country_id Country  Cloudiness (%)  \
# 0            Boulder       Colorado     5574991      US              40
# 1         Santa Cruz     California     5393052      US               1
# 2        Watsonville     California     5407529      US               1
# 4       Fort Collins       Colorado     5577147      US              40
# 5    San Luis Obispo     California     5392323      US               1
# 6           San Jose     California     1689431      PH              44
# 7              Provo           Utah     5780026      US               1
# 8         Bridgeport    Connecticut     5282804      US              75
# 9           Stamford    Connecticut     4843564      US              90
# 10           Norwalk    Connecticut     5377995      US               1
# 11        Barnstable  Massachusetts     4929771      US              75
# 12         Anchorage         Alaska     5879400      US              75
# 13            Naples        Florida     4165565      US               1
# 14         Immokalee        Florida     4159553      US              90
# 15      Marco Island        Florida     4163384      US              75
# 16       Santa Maria     California     3450083      BR              75
# 17     Santa Barbara     California     5392952      US               1
# 18            Salina     California     4550364      US              40
# 19        North Port        Florida     4166274      US              90
# 20          Sarasota        Florida     4172131      US              90
# 21         Bradenton        Florida     4148708      US              40
# 8                 42.08           41.17           -73.20            67
# 9                 42.08           41.05           -73.54            63
# 10                66.02           33.91          -118.08            51
# 11                48.92           41.70           -70.30           100
# 12                42.26           61.22          -149.89            82
# 13                66.20           26.14           -81.79            87
# 14                66.20           26.42           -81.42            77
# 15                66.20           25.94           -81.72            93
# 16                77.00          -29.69           -53.81            83
# 17                71.06           34.42          -119.70            55
# 18                30.20           36.29           -95.15            58
# 19                64.40           27.04           -82.24            72
# 20                64.40           27.34           -82.53            72
# 21                62.06           27.50           -82.57            74
# 22                80.06           21.30          -157.86            78
# 23                25.70           42.27           -83.73            80
# 24                60.80           37.78          -122.42            63
# 25                60.80           37.80          -122.27            63
# 26                60.80           37.67          -122.08            63
# 27                23.00           38.83          -104.83            91
# 28                44.96           43.00           -71.45            70
# 29                44.96           42.77           -71.47            70
# 30                71.06           34.20          -119.18            28
# 31                68.00           34.17          -118.84            28
# 32                71.06           34.28          -119.29            55
# 36                -2.93           44.98           -93.27            57
# 37                -2.21           44.95           -93.10            61
# 38                10.40           40.47           -88.99            76
# 39                66.92           32.72          -117.16            62
# 40                26.60           50.23            12.87            92
# 41                48.92           45.52          -122.67            70
# 42                52.16           30.27           -97.74            44
#
#     UV_Index  Wind Speed (mph)  Ranking  Rainfall  Sunshine
# 0       4.29              3.36        1      15.9       136
# 1       4.63              4.70        2      22.2       146
# 2       4.65              4.70        3      22.2       146
# 4       4.23              3.36        5      15.9       136
# 5       4.70             10.29        6      22.2       146
# 6       4.47              3.85        7      22.2       146
# 7       4.31              3.36        8      12.2       125
# 8       4.78             16.11        9      50.3        82
# 9       4.76             12.75       10      50.3        82
# 10      4.61              4.70       11      50.3        82
# 11      4.89              8.05       12      47.7        98
# 12      4.55             12.75       13      22.5        61
# 13      4.33              7.20       14      54.5       101
# 14      4.37              7.20       15      54.5       101
# 15      4.34              8.77       16      54.5       101
# 16      4.58             11.41       17      22.2       146
# 17      4.70              4.74       18      22.2       146
# 18      4.02              6.93       19      22.2       146
# 19      4.31             10.29       20      54.5       101
# 20      4.28             10.29       21      54.5       101
# 21      4.28              8.05       22      54.5       101
# 22      4.46              6.93       23      63.7        90
# 23      4.23             17.22       24      32.8        71
# 24      4.62              4.07       25      22.2       146
# 25      4.62              4.07       26      22.2       146
# 26      4.63              2.62       27      22.2       146
# 27      4.23              6.93       28      15.9       136
# 28      3.57             10.29       29      43.4        90
# 29      4.84             10.29       30      43.4        90
# 30      4.67             12.75       31      22.2       146
# 31      4.65             12.75       32      22.2       146
# 32      4.69              3.96       33      22.2       146
# 36      4.01             11.41       37      27.3        95
# 37      4.01             12.75       38      27.3        95
# 38      4.16             24.16       39      27.3        95
# 39      4.57              6.93       40      22.2       146
# 40      3.24              5.82       41      22.2       146
# 41      4.61              2.28       42      42.2       101
# 42      4.09              5.82       43      28.9       135

# %%
#Convert dataframe to scatter plot
#Format for scatter plot is plt.scatter(x_axis, y_axis, s=whatever size, marker='o', alpha= transparency, 
#edgecolors = color,  and other options)

plt.scatter(weather_df['Ranking'], weather_df['Rainfall'], linewidth=1, edgecolors='black', marker='|', s=400)

plt.xlabel('Ranking')
plt.ylabel('Rainfall (inches)')
plt.title('Rainfall by Ranking')


#save as png
plt.savefig("Rainfall_by_Ranking")
#show the plot
plt.show()

# %%
# first start by creating blank lists for our columns/data we wanna retrieve

uvlist = []


#Then construct the URL
#make sure to use imperial
#start with a base
base_url = 'http://api.openweathermap.org/data/2.5/uvi?'

# http://api.openweathermap.org/data/2.5/uvi?appid=558e56b6dce2cececb94ac03459570d9&lat=40.02&lon=-105.27

#then add your api key and create a unique url for every city in cities (list i created earlier)
#everything has to be in lists
#open weather api is as follows: http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=558e56b6dce2cececb94ac03459570d9&q=houston

x=0

for lat in latlist:
    query_url = base_url + '&appid=' + str(api_key) + '&lat=' + str(lat)
#     response = requests.get(query_url)
#     json_response = response.json()
#     uvlist.append(json_response["value"])
#     x + 1
#     print(query_url)

for lon in lonlist:
    new_url = query_url + '&lon=' + str(lon)
    response = requests.get(new_url)
    json_response = response.json()
    uvlist.append(json_response["value"])

# %%
uvlist
# Out:
# [3.9,
#  4.56,
#  4.54,
#  4.56,
#  3.86,
#  4.53,
#  5.08,
#  4.06,
#  4.61,
#  4.59,
#  4.5,
#  4.73,
#  4.36,
#  4.48,
#  4.5,
#  4.48,
#  4.9,
#  4.53,
#  3.57,
#  4.46,
#  4.45,
#  4.45,
#  4.75,
#  4.39,
#  4.57,
#  4.57,
#  4.56,
#  3.86,
#  4.7,
#  4.7,
#  4.52,
#  4.52,
#  4.53,
#  4.52,
#  4.52,
#  3.63,
#  3.59,
#  3.6,
#  3.94,
#  4.47,
#  3.33,
#  4.58,
#  3.56]

# %%
#Convert dataframe to scatter plot
#Format for scatter plot is plt.scatter(x_axis, y_axis, s=whatever size, marker='o', alpha= transparency, 
#edgecolors = color,  and other options)

plt.scatter(weather_df['Ranking'], weather_df['UV_Index'], linewidth=1, edgecolors='black', color='yellow', s=300)

plt.xlabel('Ranking')
plt.ylabel('UV Index')
plt.title('Sunniness by Ranking')

#save as png
plt.savefig("Sunniness_by_Ranking")
#show the plot
plt.show()

# %%
#Convert dataframe to scatter plot
#Format for scatter plot is plt.scatter(x_axis, y_axis, s=whatever size, marker='o', alpha= transparency, 
#edgecolors = color,  and other options)

plt.scatter(weather_df['Ranking'], weather_df['Sunshine'], linewidth=1, edgecolors='black', color='yellow', s=300)

plt.xlabel('Ranking')
plt.ylabel('Sunshine (in days)')
plt.title('Sunshine by Ranking')

#save as png
plt.savefig("Sunshine_by_Ranking")
#show the plot
plt.show()

# %%
#Convert dataframe to scatter plot
#Format for scatter plot is plt.scatter(x_axis, y_axis, s=whatever size, marker='o', alpha= transparency, 
#edgecolors = color,  and other options)

plt.scatter(weather_df['Ranking'], weather_df['Snow'], linewidth=1, edgecolors='black', color='blue', s=100, marker="*")

plt.xlabel('Ranking')
plt.ylabel('Snowfall (inches)')
plt.title('Happy Cities Snowfall by Ranking')

#save as png
plt.savefig("Happy_Snow_by_Ranking")
#show the plot
plt.show()

# %%
#Convert this dataframe to a csv and put in in the Output folder
#Format is dfname.to_csv("folder/filename.csv", index=False)
weather_df.to_csv('top_25_weather.csv', index=False)
